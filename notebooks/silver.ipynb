# %% [markdown]
# ## Bronze to Silver: Data Cleaning and Transformation for Dimension Tables

# %% [markdown]
# ### Import Library

# %%
import duckdb
import pandas as pd

# %% [markdown]
# ### Connect Database

# %%
# Connect database
try:
    con = duckdb.connect("../data/finance_analytics_light_raw.duckdb")
    print("✅Successfully connected to the database")
except ValueError as e:
    print(f"Failed connected to the database{e}")
# Out:
# ✅Successfully connected to the database

# %% [markdown]
# ### Show Schema

# %%
# Show All Schema
con.sql(
    """
    SHOW SCHEMAS
    """
)
# Out:
# ┌─────────────────────────────┬─────────────┬─────────┐
# │        database_name        │ schema_name │ current │
# │           varchar           │   varchar   │ boolean │
# ├─────────────────────────────┼─────────────┼─────────┤
# │ finance_analytics_light_raw │ bronze      │ false   │
# │ finance_analytics_light_raw │ gold        │ false   │
# │ finance_analytics_light_raw │ main        │ true    │
# │ finance_analytics_light_raw │ silver      │ false   │
# └─────────────────────────────┴─────────────┴─────────┘

# %%
# Show all tables from bronze schema
con.sql(
    """
    SHOW TABLES FROM finance_analytics_light_raw.bronze
    """
)
# Out:
# ┌─────────────────┐
# │      name       │
# │     varchar     │
# ├─────────────────┤
# │ account_mapping │
# │ accounts        │
# │ geography       │
# │ gl_transactions │
# │ stores          │
# └─────────────────┘

# %% [markdown]
# ### Accounts

# %%
# Check bronze.accounts table
con.sql(
    """
    SELECT
    *
    FROM bronze.accounts
    """
)
# Out:
# ┌────────────────┬────────────────────┬───────────────────┬──────────┐
# │ account_number │    account_name    │   account_type    │ currency │
# │    varchar     │      varchar       │      varchar      │ varchar  │
# ├────────────────┼────────────────────┼───────────────────┼──────────┤
# │ 3000           │ Product Sales      │ Revenue           │ NOK      │
# │ 4000           │ Cost of Goods Sold │ COGS              │ NOK      │
# │ 5000           │ Salaries & Wages   │ Operating Expense │ NOK      │
# │ 5100           │ Rent Expense       │ Operating Expense │ NOK      │
# │ 5200           │ Marketing Expense  │ Operating Expense │ NOK      │
# │ 7000           │ Interest Expense   │ Financial         │ NOK      │
# └────────────────┴────────────────────┴───────────────────┴──────────┘

# %% [markdown]
# #### Silver Accounts

# %%
# Create silver accounts table
try:
    con.execute(
        """
        CREATE OR REPLACE TABLE silver.accounts AS 
        SELECT
            CAST(account_number AS INTEGER)     AS account_number,
            TRIM(account_name)                  AS account_name,
            UPPER(TRIM(account_type))           AS account_type,
            UPPER(TRIM(currency))               AS currency,
        FROM bronze.accounts
        """
    )
    print("✅ Created silver accounts table")
except ValueError as error:
    print(f"Failed create silver accounts table, {error}")
# Out:
# ✅ Created silver accounts table

# %%
# Check silver accounts table
con.sql(
    """
    SELECT
    *
    FROM silver.accounts
    """
)
# Out:
# ┌────────────────┬────────────────────┬───────────────────┬──────────┐
# │ account_number │    account_name    │   account_type    │ currency │
# │     int32      │      varchar       │      varchar      │ varchar  │
# ├────────────────┼────────────────────┼───────────────────┼──────────┤
# │           3000 │ Product Sales      │ REVENUE           │ NOK      │
# │           4000 │ Cost of Goods Sold │ COGS              │ NOK      │
# │           5000 │ Salaries & Wages   │ OPERATING EXPENSE │ NOK      │
# │           5100 │ Rent Expense       │ OPERATING EXPENSE │ NOK      │
# │           5200 │ Marketing Expense  │ OPERATING EXPENSE │ NOK      │
# │           7000 │ Interest Expense   │ FINANCIAL         │ NOK      │
# └────────────────┴────────────────────┴───────────────────┴──────────┘

# %% [markdown]
# ### General ledger transactions

# %%
# Check bronze gl transactions table
con.sql(
    """
    SELECT
    *
    FROM bronze.gl_transactions
    """
)
# Out:
# ┌────────────────┬──────────────────┬────────────┬────────────────┬──────────────┬──────────┬─────────────────┬──────────────────────────────────────────────┐
# │ transaction_id │ transaction_date │ store_code │ account_number │ amount_local │ currency │ document_number │                 description                  │
# │     int64      │       date       │  varchar   │     int32      │    double    │ varchar  │     varchar     │                   varchar                    │
# ├────────────────┼──────────────────┼────────────┼────────────────┼──────────────┼──────────┼─────────────────┼──────────────────────────────────────────────┤
# │              1 │ 2025-03-12       │ SE001      │           4000 │     -7149.34 │ NOK      │ DOC-2025-000001 │ Cost of Goods Sold - Recently thought month. │
# │              2 │ 2025-09-24       │ SE001      │           4000 │     -6023.02 │ NOK      │ DOC-2025-000002 │ Cost of Goods Sold - Per send.               │
# │              3 │ 2026-05-23       │ SE001      │           5200 │     -6945.75 │ NOK      │ DOC-2026-000003 │ Marketing Expense - Meeting woman already.   │
# │              4 │ 2026-09-30       │ NO001      │           5200 │     -8364.08 │ NOK      │ DOC-2026-000004 │ Marketing Expense - Rock American story.     │
# │              5 │ 2025-06-23       │ NO002      │           4000 │     -6059.68 │ NOK      │ DOC-2025-000005 │ Cost of Goods Sold - Teacher learn.          │
# │              6 │ 2026-04-06       │ NO003      │           3000 │     10433.85 │ NOK      │ DOC-2026-000006 │ Product Sales - Area current.                │
# │              7 │ 2025-06-03       │ NO002      │           5200 │     -2129.26 │ NOK      │ DOC-2025-000007 │ Marketing Expense - Other drug thus.         │
# │              8 │ 2025-02-10       │ NO001      │           7000 │     -1910.74 │ NOK      │ DOC-2025-000008 │ Interest Expense - Appear hear dog yourself. │
# │              9 │ 2025-12-24       │ EC_NO      │           3000 │       1141.0 │ NOK      │ DOC-2025-000009 │ Product Sales - Follow nice hope.            │
# │             10 │ 2025-12-01       │ NO003      │           5000 │     -6067.93 │ NOK      │ DOC-2025-000010 │ Salaries & Wages - Night cover.              │
# │              · │     ·            │   ·        │             ·  │         ·    │  ·       │        ·        │                ·                             │
# │              · │     ·            │   ·        │             ·  │         ·    │  ·       │        ·        │                ·                             │
# │              · │     ·            │   ·        │             ·  │         ·    │  ·       │        ·        │                ·                             │
# │           9991 │ 2026-06-20       │ EC_SE      │           5100 │     -4647.26 │ NOK      │ DOC-2026-009991 │ Rent Expense - Buy significant outside.      │
# │           9992 │ 2026-01-04       │ SE001      │           5000 │     -7984.27 │ NOK      │ DOC-2026-009992 │ Salaries & Wages - Skin less raise.          │
# │           9993 │ 2025-03-05       │ EC_SE      │           5200 │     -6937.35 │ NOK      │ DOC-2025-009993 │ Marketing Expense - Section Republican.      │
# │           9994 │ 2025-12-07       │ NO001      │           5000 │     -5634.18 │ NOK      │ DOC-2025-009994 │ Salaries & Wages - Modern policy.            │
# │           9995 │ 2025-10-29       │ NO003      │           7000 │      -6987.2 │ NOK      │ DOC-2025-009995 │ Interest Expense - How Republican century.   │
# │           9996 │ 2026-06-24       │ SE001      │           5000 │     -6636.74 │ NOK      │ DOC-2026-009996 │ Salaries & Wages - Sit citizen expert above. │
# │           9997 │ 2026-07-06       │ NO002      │           5200 │     -1930.55 │ NOK      │ DOC-2026-009997 │ Marketing Expense - From rich program.       │
# │           9998 │ 2025-11-12       │ EC_SE      │           5000 │     -2190.22 │ NOK      │ DOC-2025-009998 │ Salaries & Wages - Also Congress.            │
# │           9999 │ 2025-09-25       │ EC_NO      │           5100 │     -2585.74 │ NOK      │ DOC-2025-009999 │ Rent Expense - Benefit site response.        │
# │          10000 │ 2025-11-24       │ EC_SE      │           4000 │     -8374.71 │ NOK      │ DOC-2025-010000 │ Cost of Goods Sold - Tonight around.         │
# └────────────────┴──────────────────┴────────────┴────────────────┴──────────────┴──────────┴─────────────────┴──────────────────────────────────────────────┘
#   ? rows (>9999 rows, 20 shown)                                                                                                                    8 columns

# %% [markdown]
# #### Silver General ledger transactions

# %%
# Create silver gl transactions table
try:
    con.execute(
        """
        CREATE OR REPLACE TABLE silver.gl_transactions AS
        SELECT
            transaction_id,
            CAST(transaction_date AS DATE) AS transaction_date,
            store_code,
            account_number,
            amount_local,
            CASE 
                WHEN amount_local >= 0 THEN 'CREDIT'
                ELSE 'DEBIT'
            END AS dc_flag,
            UPPER(TRIM(currency))                   AS currency,
            document_number,
            TRIM(description)                       AS description
        FROM bronze.gl_transactions
        """
    )
    print("✅ Created silver gl_transactions table")
except ValueError as error:
    print(f"Failed create silver gl_transactions table, {error}")
# Out:
# ✅ Created silver gl_transactions table

# %%
# Check silver gl_transactions table
con.sql(
    """
    SELECT
    *
    FROM silver.gl_transactions
    """
)
# Out:
# ┌────────────────┬──────────────────┬────────────┬────────────────┬──────────────┬─────────┬──────────┬─────────────────┬──────────────────────────────────────────────┐
# │ transaction_id │ transaction_date │ store_code │ account_number │ amount_local │ dc_flag │ currency │ document_number │                 description                  │
# │     int64      │       date       │  varchar   │     int32      │    double    │ varchar │ varchar  │     varchar     │                   varchar                    │
# ├────────────────┼──────────────────┼────────────┼────────────────┼──────────────┼─────────┼──────────┼─────────────────┼──────────────────────────────────────────────┤
# │              1 │ 2025-03-12       │ SE001      │           4000 │     -7149.34 │ DEBIT   │ NOK      │ DOC-2025-000001 │ Cost of Goods Sold - Recently thought month. │
# │              2 │ 2025-09-24       │ SE001      │           4000 │     -6023.02 │ DEBIT   │ NOK      │ DOC-2025-000002 │ Cost of Goods Sold - Per send.               │
# │              3 │ 2026-05-23       │ SE001      │           5200 │     -6945.75 │ DEBIT   │ NOK      │ DOC-2026-000003 │ Marketing Expense - Meeting woman already.   │
# │              4 │ 2026-09-30       │ NO001      │           5200 │     -8364.08 │ DEBIT   │ NOK      │ DOC-2026-000004 │ Marketing Expense - Rock American story.     │
# │              5 │ 2025-06-23       │ NO002      │           4000 │     -6059.68 │ DEBIT   │ NOK      │ DOC-2025-000005 │ Cost of Goods Sold - Teacher learn.          │
# │              6 │ 2026-04-06       │ NO003      │           3000 │     10433.85 │ CREDIT  │ NOK      │ DOC-2026-000006 │ Product Sales - Area current.                │
# │              7 │ 2025-06-03       │ NO002      │           5200 │     -2129.26 │ DEBIT   │ NOK      │ DOC-2025-000007 │ Marketing Expense - Other drug thus.         │
# │              8 │ 2025-02-10       │ NO001      │           7000 │     -1910.74 │ DEBIT   │ NOK      │ DOC-2025-000008 │ Interest Expense - Appear hear dog yourself. │
# │              9 │ 2025-12-24       │ EC_NO      │           3000 │       1141.0 │ CREDIT  │ NOK      │ DOC-2025-000009 │ Product Sales - Follow nice hope.            │
# │             10 │ 2025-12-01       │ NO003      │           5000 │     -6067.93 │ DEBIT   │ NOK      │ DOC-2025-000010 │ Salaries & Wages - Night cover.              │
# │              · │     ·            │   ·        │             ·  │         ·    │   ·     │  ·       │        ·        │                ·                             │
# │              · │     ·            │   ·        │             ·  │         ·    │   ·     │  ·       │        ·        │                ·                             │
# │              · │     ·            │   ·        │             ·  │         ·    │   ·     │  ·       │        ·        │                ·                             │
# │           9991 │ 2026-06-20       │ EC_SE      │           5100 │     -4647.26 │ DEBIT   │ NOK      │ DOC-2026-009991 │ Rent Expense - Buy significant outside.      │
# │           9992 │ 2026-01-04       │ SE001      │           5000 │     -7984.27 │ DEBIT   │ NOK      │ DOC-2026-009992 │ Salaries & Wages - Skin less raise.          │
# │           9993 │ 2025-03-05       │ EC_SE      │           5200 │     -6937.35 │ DEBIT   │ NOK      │ DOC-2025-009993 │ Marketing Expense - Section Republican.      │
# │           9994 │ 2025-12-07       │ NO001      │           5000 │     -5634.18 │ DEBIT   │ NOK      │ DOC-2025-009994 │ Salaries & Wages - Modern policy.            │
# │           9995 │ 2025-10-29       │ NO003      │           7000 │      -6987.2 │ DEBIT   │ NOK      │ DOC-2025-009995 │ Interest Expense - How Republican century.   │
# │           9996 │ 2026-06-24       │ SE001      │           5000 │     -6636.74 │ DEBIT   │ NOK      │ DOC-2026-009996 │ Salaries & Wages - Sit citizen expert above. │
# │           9997 │ 2026-07-06       │ NO002      │           5200 │     -1930.55 │ DEBIT   │ NOK      │ DOC-2026-009997 │ Marketing Expense - From rich program.       │
# │           9998 │ 2025-11-12       │ EC_SE      │           5000 │     -2190.22 │ DEBIT   │ NOK      │ DOC-2025-009998 │ Salaries & Wages - Also Congress.            │
# │           9999 │ 2025-09-25       │ EC_NO      │           5100 │     -2585.74 │ DEBIT   │ NOK      │ DOC-2025-009999 │ Rent Expense - Benefit site response.        │
# │          10000 │ 2025-11-24       │ EC_SE      │           4000 │     -8374.71 │ DEBIT   │ NOK      │ DOC-2025-010000 │ Cost of Goods Sold - Tonight around.         │
# └────────────────┴──────────────────┴────────────┴────────────────┴──────────────┴─────────┴──────────┴─────────────────┴──────────────────────────────────────────────┘
#   ? rows (>9999 rows, 20 shown)                                                                                                                              9 columns

# %% [markdown]
# ### Stores

# %%
# Check bronze stores table
con.sql(
    """
    SELECT
    *
    FROM bronze.stores
    """
)
# Out:
# ┌────────────┬───────────────────┬────────────┐
# │ store_code │    store_name     │ store_type │
# │  varchar   │      varchar      │  varchar   │
# ├────────────┼───────────────────┼────────────┤
# │ NO001      │ NRG Oslo City     │ Store      │
# │ NO002      │ NRG Bergen        │ Store      │
# │ NO003      │ NRG Trondheim     │ Store      │
# │ SE001      │ NRG Stockholm     │ Store      │
# │ SE002      │ NRG Gothenburg    │ Store      │
# │ EC_NO      │ NRG Online Norway │ Ecom       │
# │ EC_SE      │ NRG Online Sweden │ Ecom       │
# └────────────┴───────────────────┴────────────┘

# %% [markdown]
# #### Silver Stores

# %%
# Create silver stores table
try:
    con.execute(
        """
        CREATE OR REPLACE TABLE silver.stores AS 
        SELECT 
            s.store_code,
            TRIM(s.store_name)        AS store_name,
            UPPER(TRIM(s.store_type)) AS store_type,
            g.country,
            g.region
        FROM bronze.stores s
        LEFT JOIN bronze.geography g
            ON s.store_code = g.store_code
        """
    )
    print("✅ Created silver stores table")
except ValueError as error:
    print(f"Failed create silver stores table, {error}")
# Out:
# ✅ Created silver stores table

# %%
# Check silver stores table
con.sql(
    """
    SELECT 
        *
    FROM silver.stores
    """
)
# Out:
# ┌────────────┬───────────────────┬────────────┬─────────┬──────────┐
# │ store_code │    store_name     │ store_type │ country │  region  │
# │  varchar   │      varchar      │  varchar   │ varchar │ varchar  │
# ├────────────┼───────────────────┼────────────┼─────────┼──────────┤
# │ NO001      │ NRG Oslo City     │ STORE      │ Norway  │ East     │
# │ NO002      │ NRG Bergen        │ STORE      │ Norway  │ West     │
# │ NO003      │ NRG Trondheim     │ STORE      │ Norway  │ Mid      │
# │ SE001      │ NRG Stockholm     │ STORE      │ Sweden  │ East     │
# │ SE002      │ NRG Gothenburg    │ STORE      │ Sweden  │ West     │
# │ EC_NO      │ NRG Online Norway │ ECOM       │ Norway  │ National │
# │ EC_SE      │ NRG Online Sweden │ ECOM       │ Sweden  │ National │
# └────────────┴───────────────────┴────────────┴─────────┴──────────┘

# %% [markdown]
# ### Account mapping

# %%
# Check bronze account_mapping table
con.sql(
    """
    SELECT
        *
    FROM bronze.account_mapping
    """
)
# Out:
# ┌───────────────┬────────────────────┬────────────────────┬───────────────┬───────────┬───────────────────────────────────────────────────────────────────┐
# │ AccountNumber │    AccountName     │       PLLine       │ StatementType │ SortOrder │                               Notes                               │
# │     int64     │      varchar       │      varchar       │    varchar    │   int64   │                              varchar                              │
# ├───────────────┼────────────────────┼────────────────────┼───────────────┼───────────┼───────────────────────────────────────────────────────────────────┤
# │          3000 │ Product Sales      │ Revenue            │ P&L           │        10 │ NULL                                                              │
# │          3010 │ Online Sales       │ Revenue            │ P&L           │        10 │ New online channel – mapping not yet confirmed                    │
# │          4000 │ Cost of Goods Sold │ COGS               │ P&L           │        20 │ NULL                                                              │
# │          4100 │ Freight Costs      │ COGS               │ P&L           │        21 │ Used occasionally – please confirm if part of COGS                │
# │          5000 │ Salaries & Wages   │ Operating Expenses │ P&L           │        30 │ NULL                                                              │
# │          5100 │ Rent Expense       │ Operating Expenses │ P&L           │        35 │ NULL                                                              │
# │          5200 │ Marketing exp      │ Operating Expenses │ P&L           │        40 │ Should this be grouped with Operating Expenses?                   │
# │          7000 │ Interest Expense   │ Financial Items    │ P&L           │        90 │ Financial cost – please confirm where it should appear in the P&L │
# └───────────────┴────────────────────┴────────────────────┴───────────────┴───────────┴───────────────────────────────────────────────────────────────────┘

# %% [markdown]
# #### Silver Account Mapping

# %%
# Create silver account_mapping table
try:
    con.execute(
        """
        CREATE OR REPLACE TABLE silver.account_mapping AS
        SELECT 
            CAST(AccountNumber AS INTEGER)  AS account_number,
            TRIM(AccountName)               AS account_name,
            TRIM(PLLine)                    AS pl_line,
            UPPER(TRIM(StatementType))      AS statement_type,
            CAST(SortOrder AS INTEGER)      AS sort_order,
            TRIM(Notes)                     AS notes
        FROM bronze.account_mapping
        """
    )
    print("✅ Created silver account mapping table")
except ValueError as error:
    print(f"Failed create silver table, {error}")
# Out:
# ✅ Created silver account mapping table

# %%
# Check silver account_mapping table
con.sql(
    """
    SELECT
        *
    FROM silver.account_mapping
    """
)
# Out:
# ┌────────────────┬────────────────────┬────────────────────┬────────────────┬────────────┬───────────────────────────────────────────────────────────────────┐
# │ account_number │    account_name    │      pl_line       │ statement_type │ sort_order │                               notes                               │
# │     int32      │      varchar       │      varchar       │    varchar     │   int32    │                              varchar                              │
# ├────────────────┼────────────────────┼────────────────────┼────────────────┼────────────┼───────────────────────────────────────────────────────────────────┤
# │           3000 │ Product Sales      │ Revenue            │ P&L            │         10 │ NULL                                                              │
# │           3010 │ Online Sales       │ Revenue            │ P&L            │         10 │ New online channel – mapping not yet confirmed                    │
# │           4000 │ Cost of Goods Sold │ COGS               │ P&L            │         20 │ NULL                                                              │
# │           4100 │ Freight Costs      │ COGS               │ P&L            │         21 │ Used occasionally – please confirm if part of COGS                │
# │           5000 │ Salaries & Wages   │ Operating Expenses │ P&L            │         30 │ NULL                                                              │
# │           5100 │ Rent Expense       │ Operating Expenses │ P&L            │         35 │ NULL                                                              │
# │           5200 │ Marketing exp      │ Operating Expenses │ P&L            │         40 │ Should this be grouped with Operating Expenses?                   │
# │           7000 │ Interest Expense   │ Financial Items    │ P&L            │         90 │ Financial cost – please confirm where it should appear in the P&L │
# └────────────────┴────────────────────┴────────────────────┴────────────────┴────────────┴───────────────────────────────────────────────────────────────────┘

# %%
con.close()
