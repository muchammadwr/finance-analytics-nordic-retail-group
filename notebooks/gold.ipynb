# %% [markdown]
# ## Silver to Gold: Building BI Ready Tables

# %% [markdown]
# ### Import Library

# %%
import duckdb
import pandas as pd

# %% [markdown]
# ### Connect Database

# %%
# Connect database
try:
    con = duckdb.connect("../data/finance_analytics_light_raw.duckdb")
    print("✅Successfully connected to the database")
except ValueError as e:
    print(f"Failed connected to the database{e}")
# Out:
# ✅Successfully connected to the database

# %% [markdown]
# ### Show Schema

# %%
# Show All Schema
con.sql(
    """
    SHOW SCHEMAS
    """
)
# Out:
# ┌─────────────────────────────┬─────────────┬─────────┐
# │        database_name        │ schema_name │ current │
# │           varchar           │   varchar   │ boolean │
# ├─────────────────────────────┼─────────────┼─────────┤
# │ finance_analytics_light_raw │ bronze      │ false   │
# │ finance_analytics_light_raw │ gold        │ false   │
# │ finance_analytics_light_raw │ main        │ true    │
# │ finance_analytics_light_raw │ silver      │ false   │
# └─────────────────────────────┴─────────────┴─────────┘

# %%
# Show all tables from silver schema
con.sql(
    """
    SHOW TABLES FROM finance_analytics_light_raw.silver
    """
)
# Out:
# ┌─────────────────┐
# │      name       │
# │     varchar     │
# ├─────────────────┤
# │ account_mapping │
# │ accounts        │
# │ gl_transactions │
# │ stores          │
# └─────────────────┘

# %% [markdown]
# ### DimAccounts

# %%
# Check silver accounts table
con.sql(
    """
    SELECT
        *
    FROM silver.accounts
    """
)
# Out:
# ┌────────────────┬────────────────────┬───────────────────┬──────────┐
# │ account_number │    account_name    │   account_type    │ currency │
# │     int32      │      varchar       │      varchar      │ varchar  │
# ├────────────────┼────────────────────┼───────────────────┼──────────┤
# │           3000 │ Product Sales      │ REVENUE           │ NOK      │
# │           4000 │ Cost of Goods Sold │ COGS              │ NOK      │
# │           5000 │ Salaries & Wages   │ OPERATING EXPENSE │ NOK      │
# │           5100 │ Rent Expense       │ OPERATING EXPENSE │ NOK      │
# │           5200 │ Marketing Expense  │ OPERATING EXPENSE │ NOK      │
# │           7000 │ Interest Expense   │ FINANCIAL         │ NOK      │
# └────────────────┴────────────────────┴───────────────────┴──────────┘

# %%
# Create gold dimensional accounts table
try:
    con.execute(
        """
        CREATE OR REPLACE TABLE gold.dim_accounts AS 
        SELECT
            account_number  AS AccountNumber,
            account_name    AS AccountName,
            account_type    AS AccountType,
            currency        AS AccountCurrency
        FROM silver.accounts
        ORDER BY AccountNumber
        """
    )
    print("✅ Created Dimensional Accounts")
except ValueError as error:
    print(f"Failed create gold dimensional accounts table, {error}")
# Out:
# ✅ Created Dimensional Accounts

# %%
# Check gold dimensional accounts
con.sql(
    """
    SELECT
        *
    FROM gold.dim_accounts
    """
)
# Out:
# ┌───────────────┬────────────────────┬───────────────────┬─────────────────┐
# │ AccountNumber │    AccountName     │    AccountType    │ AccountCurrency │
# │     int32     │      varchar       │      varchar      │     varchar     │
# ├───────────────┼────────────────────┼───────────────────┼─────────────────┤
# │          3000 │ Product Sales      │ REVENUE           │ NOK             │
# │          4000 │ Cost of Goods Sold │ COGS              │ NOK             │
# │          5000 │ Salaries & Wages   │ OPERATING EXPENSE │ NOK             │
# │          5100 │ Rent Expense       │ OPERATING EXPENSE │ NOK             │
# │          5200 │ Marketing Expense  │ OPERATING EXPENSE │ NOK             │
# │          7000 │ Interest Expense   │ FINANCIAL         │ NOK             │
# └───────────────┴────────────────────┴───────────────────┴─────────────────┘

# %% [markdown]
# ### DimStores

# %%
# Check silver stores table
con.sql(
    """
    SELECT
        *
    FROM silver.stores
    """
)
# Out:
# ┌────────────┬───────────────────┬────────────┬─────────┬──────────┐
# │ store_code │    store_name     │ store_type │ country │  region  │
# │  varchar   │      varchar      │  varchar   │ varchar │ varchar  │
# ├────────────┼───────────────────┼────────────┼─────────┼──────────┤
# │ NO001      │ NRG Oslo City     │ STORE      │ Norway  │ East     │
# │ NO002      │ NRG Bergen        │ STORE      │ Norway  │ West     │
# │ NO003      │ NRG Trondheim     │ STORE      │ Norway  │ Mid      │
# │ SE001      │ NRG Stockholm     │ STORE      │ Sweden  │ East     │
# │ SE002      │ NRG Gothenburg    │ STORE      │ Sweden  │ West     │
# │ EC_NO      │ NRG Online Norway │ ECOM       │ Norway  │ National │
# │ EC_SE      │ NRG Online Sweden │ ECOM       │ Sweden  │ National │
# └────────────┴───────────────────┴────────────┴─────────┴──────────┘

# %%
# Create gold dimensional stores table
try:
    con.execute(
        """
        CREATE OR REPLACE TABLE gold.dim_stores AS 
        SELECT
            store_code              AS StoreCode,
            TRIM(store_name)        AS StoreName,
            UPPER(TRIM(store_type)) AS StoreType,
            country                 AS Country,
            region                  AS Region
        FROM silver.stores
        ORDER BY StoreCode
        """
    )
    print("✅ Created dimensional stores table")
except ValueError as error:
    print(f"Failed create gold dimensional stores table, {error}")
# Out:
# ✅ Created dimensional stores table

# %%
# Check dimensional stores table
con.sql(
    """
    SELECT
        *
    FROM gold.dim_stores
    """
)
# Out:
# ┌───────────┬───────────────────┬───────────┬─────────┬──────────┐
# │ StoreCode │     StoreName     │ StoreType │ Country │  Region  │
# │  varchar  │      varchar      │  varchar  │ varchar │ varchar  │
# ├───────────┼───────────────────┼───────────┼─────────┼──────────┤
# │ EC_NO     │ NRG Online Norway │ ECOM      │ Norway  │ National │
# │ EC_SE     │ NRG Online Sweden │ ECOM      │ Sweden  │ National │
# │ NO001     │ NRG Oslo City     │ STORE     │ Norway  │ East     │
# │ NO002     │ NRG Bergen        │ STORE     │ Norway  │ West     │
# │ NO003     │ NRG Trondheim     │ STORE     │ Norway  │ Mid      │
# │ SE001     │ NRG Stockholm     │ STORE     │ Sweden  │ East     │
# │ SE002     │ NRG Gothenburg    │ STORE     │ Sweden  │ West     │
# └───────────┴───────────────────┴───────────┴─────────┴──────────┘

# %% [markdown]
# ### DimAccountMapping

# %%
# Check silver accounts mapping
con.sql(
    """
    SELECT
        *
    FROM silver.account_mapping    
    """
)
# Out:
# ┌────────────────┬────────────────────┬────────────────────┬────────────────┬────────────┬───────────────────────────────────────────────────────────────────┐
# │ account_number │    account_name    │      pl_line       │ statement_type │ sort_order │                               notes                               │
# │     int32      │      varchar       │      varchar       │    varchar     │   int32    │                              varchar                              │
# ├────────────────┼────────────────────┼────────────────────┼────────────────┼────────────┼───────────────────────────────────────────────────────────────────┤
# │           3000 │ Product Sales      │ Revenue            │ P&L            │         10 │ NULL                                                              │
# │           3010 │ Online Sales       │ Revenue            │ P&L            │         10 │ New online channel – mapping not yet confirmed                    │
# │           4000 │ Cost of Goods Sold │ COGS               │ P&L            │         20 │ NULL                                                              │
# │           4100 │ Freight Costs      │ COGS               │ P&L            │         21 │ Used occasionally – please confirm if part of COGS                │
# │           5000 │ Salaries & Wages   │ Operating Expenses │ P&L            │         30 │ NULL                                                              │
# │           5100 │ Rent Expense       │ Operating Expenses │ P&L            │         35 │ NULL                                                              │
# │           5200 │ Marketing exp      │ Operating Expenses │ P&L            │         40 │ Should this be grouped with Operating Expenses?                   │
# │           7000 │ Interest Expense   │ Financial Items    │ P&L            │         90 │ Financial cost – please confirm where it should appear in the P&L │
# └────────────────┴────────────────────┴────────────────────┴────────────────┴────────────┴───────────────────────────────────────────────────────────────────┘

# %%
# Create dimensional account mapping
try:
    con.execute(
        """
        CREATE OR REPLACE TABLE gold.dim_account_mapping AS
        SELECT 
            account_number  AS AccountNumber,
            account_name    AS AccountName,
            pl_line         AS PLLine,
            statement_type  AS StatementType,
            sort_order      AS SortOrder,
            notes           AS Notes
        FROM silver.account_mapping
        ORDER BY SortOrder, AccountNumber
        """
    )
    print("✅ Created gold dimensional account mapping table")
except ValueError as error:
    print(f"Failed create gold dimensional account mapping table, {error}")
# Out:
# ✅ Created gold dimensional account mapping table

# %%
# Check dimensional account mapping table
con.sql(
    """
    SELECT
    *
    FROM gold.dim_account_mapping
    """
)
# Out:
# ┌───────────────┬────────────────────┬────────────────────┬───────────────┬───────────┬───────────────────────────────────────────────────────────────────┐
# │ AccountNumber │    AccountName     │       PLLine       │ StatementType │ SortOrder │                               Notes                               │
# │     int32     │      varchar       │      varchar       │    varchar    │   int32   │                              varchar                              │
# ├───────────────┼────────────────────┼────────────────────┼───────────────┼───────────┼───────────────────────────────────────────────────────────────────┤
# │          3000 │ Product Sales      │ Revenue            │ P&L           │        10 │ NULL                                                              │
# │          3010 │ Online Sales       │ Revenue            │ P&L           │        10 │ New online channel – mapping not yet confirmed                    │
# │          4000 │ Cost of Goods Sold │ COGS               │ P&L           │        20 │ NULL                                                              │
# │          4100 │ Freight Costs      │ COGS               │ P&L           │        21 │ Used occasionally – please confirm if part of COGS                │
# │          5000 │ Salaries & Wages   │ Operating Expenses │ P&L           │        30 │ NULL                                                              │
# │          5100 │ Rent Expense       │ Operating Expenses │ P&L           │        35 │ NULL                                                              │
# │          5200 │ Marketing exp      │ Operating Expenses │ P&L           │        40 │ Should this be grouped with Operating Expenses?                   │
# │          7000 │ Interest Expense   │ Financial Items    │ P&L           │        90 │ Financial cost – please confirm where it should appear in the P&L │
# └───────────────┴────────────────────┴────────────────────┴───────────────┴───────────┴───────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ### FactGLTransactions

# %%
# Check silver gl transactions table
con.sql(
    """
    SELECT
    *
    FROM silver.gl_transactions
    """
)
# Out:
# ┌────────────────┬──────────────────┬────────────┬────────────────┬──────────────┬─────────┬──────────┬─────────────────┬──────────────────────────────────────────────┐
# │ transaction_id │ transaction_date │ store_code │ account_number │ amount_local │ dc_flag │ currency │ document_number │                 description                  │
# │     int64      │       date       │  varchar   │     int32      │    double    │ varchar │ varchar  │     varchar     │                   varchar                    │
# ├────────────────┼──────────────────┼────────────┼────────────────┼──────────────┼─────────┼──────────┼─────────────────┼──────────────────────────────────────────────┤
# │              1 │ 2025-03-12       │ SE001      │           4000 │     -7149.34 │ DEBIT   │ NOK      │ DOC-2025-000001 │ Cost of Goods Sold - Recently thought month. │
# │              2 │ 2025-09-24       │ SE001      │           4000 │     -6023.02 │ DEBIT   │ NOK      │ DOC-2025-000002 │ Cost of Goods Sold - Per send.               │
# │              3 │ 2026-05-23       │ SE001      │           5200 │     -6945.75 │ DEBIT   │ NOK      │ DOC-2026-000003 │ Marketing Expense - Meeting woman already.   │
# │              4 │ 2026-09-30       │ NO001      │           5200 │     -8364.08 │ DEBIT   │ NOK      │ DOC-2026-000004 │ Marketing Expense - Rock American story.     │
# │              5 │ 2025-06-23       │ NO002      │           4000 │     -6059.68 │ DEBIT   │ NOK      │ DOC-2025-000005 │ Cost of Goods Sold - Teacher learn.          │
# │              6 │ 2026-04-06       │ NO003      │           3000 │     10433.85 │ CREDIT  │ NOK      │ DOC-2026-000006 │ Product Sales - Area current.                │
# │              7 │ 2025-06-03       │ NO002      │           5200 │     -2129.26 │ DEBIT   │ NOK      │ DOC-2025-000007 │ Marketing Expense - Other drug thus.         │
# │              8 │ 2025-02-10       │ NO001      │           7000 │     -1910.74 │ DEBIT   │ NOK      │ DOC-2025-000008 │ Interest Expense - Appear hear dog yourself. │
# │              9 │ 2025-12-24       │ EC_NO      │           3000 │       1141.0 │ CREDIT  │ NOK      │ DOC-2025-000009 │ Product Sales - Follow nice hope.            │
# │             10 │ 2025-12-01       │ NO003      │           5000 │     -6067.93 │ DEBIT   │ NOK      │ DOC-2025-000010 │ Salaries & Wages - Night cover.              │
# │              · │     ·            │   ·        │             ·  │         ·    │   ·     │  ·       │        ·        │                ·                             │
# │              · │     ·            │   ·        │             ·  │         ·    │   ·     │  ·       │        ·        │                ·                             │
# │              · │     ·            │   ·        │             ·  │         ·    │   ·     │  ·       │        ·        │                ·                             │
# │           9991 │ 2026-06-20       │ EC_SE      │           5100 │     -4647.26 │ DEBIT   │ NOK      │ DOC-2026-009991 │ Rent Expense - Buy significant outside.      │
# │           9992 │ 2026-01-04       │ SE001      │           5000 │     -7984.27 │ DEBIT   │ NOK      │ DOC-2026-009992 │ Salaries & Wages - Skin less raise.          │
# │           9993 │ 2025-03-05       │ EC_SE      │           5200 │     -6937.35 │ DEBIT   │ NOK      │ DOC-2025-009993 │ Marketing Expense - Section Republican.      │
# │           9994 │ 2025-12-07       │ NO001      │           5000 │     -5634.18 │ DEBIT   │ NOK      │ DOC-2025-009994 │ Salaries & Wages - Modern policy.            │
# │           9995 │ 2025-10-29       │ NO003      │           7000 │      -6987.2 │ DEBIT   │ NOK      │ DOC-2025-009995 │ Interest Expense - How Republican century.   │
# │           9996 │ 2026-06-24       │ SE001      │           5000 │     -6636.74 │ DEBIT   │ NOK      │ DOC-2026-009996 │ Salaries & Wages - Sit citizen expert above. │
# │           9997 │ 2026-07-06       │ NO002      │           5200 │     -1930.55 │ DEBIT   │ NOK      │ DOC-2026-009997 │ Marketing Expense - From rich program.       │
# │           9998 │ 2025-11-12       │ EC_SE      │           5000 │     -2190.22 │ DEBIT   │ NOK      │ DOC-2025-009998 │ Salaries & Wages - Also Congress.            │
# │           9999 │ 2025-09-25       │ EC_NO      │           5100 │     -2585.74 │ DEBIT   │ NOK      │ DOC-2025-009999 │ Rent Expense - Benefit site response.        │
# │          10000 │ 2025-11-24       │ EC_SE      │           4000 │     -8374.71 │ DEBIT   │ NOK      │ DOC-2025-010000 │ Cost of Goods Sold - Tonight around.         │
# └────────────────┴──────────────────┴────────────┴────────────────┴──────────────┴─────────┴──────────┴─────────────────┴──────────────────────────────────────────────┘
#   ? rows (>9999 rows, 20 shown)                                                                                                                              9 columns

# %%
# Create fact gl transactions table
try:
    con.execute(
        """
        CREATE OR REPLACE TABLE gold.fact_gl_transactions AS
        SELECT
            transaction_id      AS TransactionID,
            transaction_date    AS TransactionDate,
            store_code          AS StoreCode,
            account_number      AS AccountNumber,
            dc_flag             AS DCFlag,
            amount_local        AS AmountLocal,
            currency            AS Currency,
            document_number     AS DocumentNumber,
            description         AS Description
        FROM silver.gl_transactions
        ORDER BY TransactionID
        """
    )
    print("✅ Created gold fact gl transactions table")
except ValueError as error:
    print(f"Failed create gold fact gl transactions table, {error}")
# Out:
# ✅ Created gold fact gl transactions table

# %%
# Check fact gl transaction table
con.sql(
    """
    SELECT
    *
    FROM gold.fact_gl_transactions
    """
)
# Out:
# ┌───────────────┬─────────────────┬───────────┬───────────────┬─────────┬─────────────┬──────────┬─────────────────┬──────────────────────────────────────────────┐
# │ TransactionID │ TransactionDate │ StoreCode │ AccountNumber │ DCFlag  │ AmountLocal │ Currency │ DocumentNumber  │                 Description                  │
# │     int64     │      date       │  varchar  │     int32     │ varchar │   double    │ varchar  │     varchar     │                   varchar                    │
# ├───────────────┼─────────────────┼───────────┼───────────────┼─────────┼─────────────┼──────────┼─────────────────┼──────────────────────────────────────────────┤
# │             1 │ 2025-03-12      │ SE001     │          4000 │ DEBIT   │    -7149.34 │ NOK      │ DOC-2025-000001 │ Cost of Goods Sold - Recently thought month. │
# │             2 │ 2025-09-24      │ SE001     │          4000 │ DEBIT   │    -6023.02 │ NOK      │ DOC-2025-000002 │ Cost of Goods Sold - Per send.               │
# │             3 │ 2026-05-23      │ SE001     │          5200 │ DEBIT   │    -6945.75 │ NOK      │ DOC-2026-000003 │ Marketing Expense - Meeting woman already.   │
# │             4 │ 2026-09-30      │ NO001     │          5200 │ DEBIT   │    -8364.08 │ NOK      │ DOC-2026-000004 │ Marketing Expense - Rock American story.     │
# │             5 │ 2025-06-23      │ NO002     │          4000 │ DEBIT   │    -6059.68 │ NOK      │ DOC-2025-000005 │ Cost of Goods Sold - Teacher learn.          │
# │             6 │ 2026-04-06      │ NO003     │          3000 │ CREDIT  │    10433.85 │ NOK      │ DOC-2026-000006 │ Product Sales - Area current.                │
# │             7 │ 2025-06-03      │ NO002     │          5200 │ DEBIT   │    -2129.26 │ NOK      │ DOC-2025-000007 │ Marketing Expense - Other drug thus.         │
# │             8 │ 2025-02-10      │ NO001     │          7000 │ DEBIT   │    -1910.74 │ NOK      │ DOC-2025-000008 │ Interest Expense - Appear hear dog yourself. │
# │             9 │ 2025-12-24      │ EC_NO     │          3000 │ CREDIT  │      1141.0 │ NOK      │ DOC-2025-000009 │ Product Sales - Follow nice hope.            │
# │            10 │ 2025-12-01      │ NO003     │          5000 │ DEBIT   │    -6067.93 │ NOK      │ DOC-2025-000010 │ Salaries & Wages - Night cover.              │
# │             · │     ·           │   ·       │            ·  │   ·     │        ·    │  ·       │        ·        │                ·                             │
# │             · │     ·           │   ·       │            ·  │   ·     │        ·    │  ·       │        ·        │                ·                             │
# │             · │     ·           │   ·       │            ·  │   ·     │        ·    │  ·       │        ·        │                ·                             │
# │          9991 │ 2026-06-20      │ EC_SE     │          5100 │ DEBIT   │    -4647.26 │ NOK      │ DOC-2026-009991 │ Rent Expense - Buy significant outside.      │
# │          9992 │ 2026-01-04      │ SE001     │          5000 │ DEBIT   │    -7984.27 │ NOK      │ DOC-2026-009992 │ Salaries & Wages - Skin less raise.          │
# │          9993 │ 2025-03-05      │ EC_SE     │          5200 │ DEBIT   │    -6937.35 │ NOK      │ DOC-2025-009993 │ Marketing Expense - Section Republican.      │
# │          9994 │ 2025-12-07      │ NO001     │          5000 │ DEBIT   │    -5634.18 │ NOK      │ DOC-2025-009994 │ Salaries & Wages - Modern policy.            │
# │          9995 │ 2025-10-29      │ NO003     │          7000 │ DEBIT   │     -6987.2 │ NOK      │ DOC-2025-009995 │ Interest Expense - How Republican century.   │
# │          9996 │ 2026-06-24      │ SE001     │          5000 │ DEBIT   │    -6636.74 │ NOK      │ DOC-2026-009996 │ Salaries & Wages - Sit citizen expert above. │
# │          9997 │ 2026-07-06      │ NO002     │          5200 │ DEBIT   │    -1930.55 │ NOK      │ DOC-2026-009997 │ Marketing Expense - From rich program.       │
# │          9998 │ 2025-11-12      │ EC_SE     │          5000 │ DEBIT   │    -2190.22 │ NOK      │ DOC-2025-009998 │ Salaries & Wages - Also Congress.            │
# │          9999 │ 2025-09-25      │ EC_NO     │          5100 │ DEBIT   │    -2585.74 │ NOK      │ DOC-2025-009999 │ Rent Expense - Benefit site response.        │
# │         10000 │ 2025-11-24      │ EC_SE     │          4000 │ DEBIT   │    -8374.71 │ NOK      │ DOC-2025-010000 │ Cost of Goods Sold - Tonight around.         │
# └───────────────┴─────────────────┴───────────┴───────────────┴─────────┴─────────────┴──────────┴─────────────────┴──────────────────────────────────────────────┘
#   ? rows (>9999 rows, 20 shown)                                                                                                                         9 columns

# %% [markdown]
# ### FactGLTransactionsMonthly

# %%
# Create gold aggregate fact gl transactions table monthly
try:
    con.execute(
        """
        CREATE OR REPLACE TABLE gold.fact_gl_transactions_monthly AS
        WITH base AS (
            SELECT 
                TransactionDate ,
                StoreCode,
                AccountNumber,
                AmountLocal
            FROM gold.fact_gl_transactions
        )
        SELECT 
            DATE_TRUNC('month', TransactionDate) AS TransactionMonth,
            StoreCode,
            AccountNumber,
            SUM(AmountLocal)            AS AmountLocal
        FROM base
        GROUP BY 
            TransactionMonth,
            StoreCode,
            AccountNumber
        ORDER BY 
            TransactionMonth,
            StoreCode,
            AccountNumber
        """
    )
    print("✅ Created gold fact gl transactions monthly table")
except ValueError as error:
    print(f"Failed create gold fact gl transactions monthly table, {error}")
# Out:
# ✅ Created gold fact gl transactions monthly table

# %%
con.sql(
    """
    SELECT
        *
    FROM gold.fact_gl_transactions_monthly
    """
)
# Out:
# ┌─────────────────────┬───────────┬───────────────┬─────────────────────┐
# │  TransactionMonth   │ StoreCode │ AccountNumber │     AmountLocal     │
# │      timestamp      │  varchar  │     int32     │       double        │
# ├─────────────────────┼───────────┼───────────────┼─────────────────────┤
# │ 2025-01-01 00:00:00 │ EC_NO     │          3000 │  128416.98999999999 │
# │ 2025-01-01 00:00:00 │ EC_NO     │          4000 │          -132913.18 │
# │ 2025-01-01 00:00:00 │ EC_NO     │          5000 │ -112326.34999999999 │
# │ 2025-01-01 00:00:00 │ EC_NO     │          5100 │  -75480.20999999999 │
# │ 2025-01-01 00:00:00 │ EC_NO     │          5200 │ -45768.810000000005 │
# │ 2025-01-01 00:00:00 │ EC_NO     │          7000 │           -68296.07 │
# │ 2025-01-01 00:00:00 │ EC_SE     │          3000 │  121805.41000000002 │
# │ 2025-01-01 00:00:00 │ EC_SE     │          4000 │ -118762.15999999999 │
# │ 2025-01-01 00:00:00 │ EC_SE     │          5000 │            -83121.2 │
# │ 2025-01-01 00:00:00 │ EC_SE     │          5100 │ -121023.70999999999 │
# │          ·          │   ·       │            ·  │           ·         │
# │          ·          │   ·       │            ·  │           ·         │
# │          ·          │   ·       │            ·  │           ·         │
# │ 2026-12-01 00:00:00 │ SE001     │          5000 │  -61294.91999999999 │
# │ 2026-12-01 00:00:00 │ SE001     │          5100 │            -92314.8 │
# │ 2026-12-01 00:00:00 │ SE001     │          5200 │ -124247.17000000001 │
# │ 2026-12-01 00:00:00 │ SE001     │          7000 │  -79007.29999999999 │
# │ 2026-12-01 00:00:00 │ SE002     │          3000 │  138649.46000000002 │
# │ 2026-12-01 00:00:00 │ SE002     │          4000 │  -87229.95999999999 │
# │ 2026-12-01 00:00:00 │ SE002     │          5000 │           -97141.86 │
# │ 2026-12-01 00:00:00 │ SE002     │          5100 │  -99930.30999999998 │
# │ 2026-12-01 00:00:00 │ SE002     │          5200 │           -56733.17 │
# │ 2026-12-01 00:00:00 │ SE002     │          7000 │           -70366.17 │
# └─────────────────────┴───────────┴───────────────┴─────────────────────┘
#   1008 rows (20 shown)                                        4 columns

# %% [markdown]
# ### FactScenarioGLTransactions

# %%
# Scenario if get a GL increase and decrease
try:
    con.execute(
        """
        CREATE OR REPLACE TABLE gold.fact_scenario_gl_transactions AS
        
        -- Aggregate transactions to month + store + account
        WITH base AS (
            SELECT
                DATE_TRUNC('month', TransactionDate) AS TransactionMonth,
                StoreCode,
                AccountNumber,
                SUM(AmountLocal)                                                    AS AmountLocal
            FROM gold.fact_gl_transactions
            GROUP BY
                TransactionMonth,
                StoreCode,
                AccountNumber
        )

        -- Actual values
        SELECT
            TransactionMonth,
            StoreCode,
            AccountNumber,
            'Actual'                                                                AS Scenario,
            AmountLocal                                                             AS AmountLocal
        FROM base

        UNION ALL

        -- Best-case scenario (revenue up, costs down)
        SELECT
            TransactionMonth,
            StoreCode,
            AccountNumber,
            'BestCase'                                                              AS Scenario,
            CASE
                WHEN AmountLocal >= 0 THEN AmountLocal * 1.10
                ELSE AmountLocal * 0.90
            END                                                                     AS AmountLocal
        FROM base

        UNION ALL

        -- Worst-case scenario (revenue down, costs up)
        SELECT
            TransactionMonth,
            StoreCode,
            AccountNumber,
            'WorstCase'                                                             AS Scenario,
            CASE
                WHEN AmountLocal >= 0 THEN AmountLocal * 0.90
                ELSE AmountLocal * 1.10
            END                                                                     AS AmountLocal
        FROM base

        ORDER BY
            TransactionMonth,
            StoreCode,
            AccountNumber,
            Scenario;
        """
    )
    print("✅ Created gold fact scenario gl transactions table")
except ValueError as error:
    print(f"Failed create gold fact scenario gl transactions table, {error}")
# Out:
# ✅ Created gold fact scenario gl transactions table

# %%
# Check gold fact scenario gl transactions table
con.sql(
    """
    SELECT
    *
    FROM gold.fact_scenario_gl_transactions
    """
)
# Out:
# ┌─────────────────────┬───────────┬───────────────┬───────────┬─────────────────────┐
# │  TransactionMonth   │ StoreCode │ AccountNumber │ Scenario  │     AmountLocal     │
# │      timestamp      │  varchar  │     int32     │  varchar  │       double        │
# ├─────────────────────┼───────────┼───────────────┼───────────┼─────────────────────┤
# │ 2025-01-01 00:00:00 │ EC_NO     │          3000 │ Actual    │  128416.98999999999 │
# │ 2025-01-01 00:00:00 │ EC_NO     │          3000 │ BestCase  │          141258.689 │
# │ 2025-01-01 00:00:00 │ EC_NO     │          3000 │ WorstCase │          115575.291 │
# │ 2025-01-01 00:00:00 │ EC_NO     │          4000 │ Actual    │          -132913.18 │
# │ 2025-01-01 00:00:00 │ EC_NO     │          4000 │ BestCase  │         -119621.862 │
# │ 2025-01-01 00:00:00 │ EC_NO     │          4000 │ WorstCase │         -146204.498 │
# │ 2025-01-01 00:00:00 │ EC_NO     │          5000 │ Actual    │ -112326.34999999999 │
# │ 2025-01-01 00:00:00 │ EC_NO     │          5000 │ BestCase  │         -101093.715 │
# │ 2025-01-01 00:00:00 │ EC_NO     │          5000 │ WorstCase │         -123558.985 │
# │ 2025-01-01 00:00:00 │ EC_NO     │          5100 │ Actual    │  -75480.20999999999 │
# │          ·          │   ·       │            ·  │   ·       │              ·      │
# │          ·          │   ·       │            ·  │   ·       │              ·      │
# │          ·          │   ·       │            ·  │   ·       │              ·      │
# │ 2026-12-01 00:00:00 │ SE002     │          5000 │ WorstCase │         -106856.046 │
# │ 2026-12-01 00:00:00 │ SE002     │          5100 │ Actual    │  -99930.30999999998 │
# │ 2026-12-01 00:00:00 │ SE002     │          5100 │ BestCase  │  -89937.27899999998 │
# │ 2026-12-01 00:00:00 │ SE002     │          5100 │ WorstCase │ -109923.34099999999 │
# │ 2026-12-01 00:00:00 │ SE002     │          5200 │ Actual    │           -56733.17 │
# │ 2026-12-01 00:00:00 │ SE002     │          5200 │ BestCase  │          -51059.853 │
# │ 2026-12-01 00:00:00 │ SE002     │          5200 │ WorstCase │          -62406.487 │
# │ 2026-12-01 00:00:00 │ SE002     │          7000 │ Actual    │           -70366.17 │
# │ 2026-12-01 00:00:00 │ SE002     │          7000 │ BestCase  │          -63329.553 │
# │ 2026-12-01 00:00:00 │ SE002     │          7000 │ WorstCase │  -77402.78700000001 │
# └─────────────────────┴───────────┴───────────────┴───────────┴─────────────────────┘
#   3024 rows (20 shown)                                                    5 columns

# %%
con.close()
